# %%
from utils import *

# %%
tags, summary = get_sellside_tags('https://baciodilatte.com.br/')
# Out:
# ============================== baciodilatte.com.br ==============================
#
# Links validated: 27 -> 8
# Fetched content from: https://baciodilatte.com.br/a-bacio
# Asking GPT to summarize the company...
# Sending description to GPT to determine tag1...
# Sending description to GPT to determine tag2...
# Sending description to GPT to determine tag3...
# Sending description to GPT to determine tag4...
# Sending description to GPT to determine tag5...

# %%
recebido = tags.to_dict('list')

# %%
res = pd.DataFrame(res).sort_values(by='Score', ascending=False).reset_index(drop=True)

# %%
res
# Out:
#                            Nome  \
# 0                          JHSF
# 1                      Iguatemi
# 2                      Iguatemi
# 3                         Allos
# 4      Jereissati Participações
# 5                  Hotéis Othon
# 6              Tronox Pigmentos
# 7                           CVC
# 8             São Paulo Turismo
# 9                  Time For Fun
# 10   General Shopping & Outlets
# 11                       Arezzo
# 12                 RaiaDrogasil
# 13               Magazine Luiza
# 14                        Cogna
# 15                 Lojas Renner
# 16                    Grupo SBF
# 17                     Grendene
# 18                          C&A
# 19                    Smart Fit
# 20               Ânima Educação
# 21                        YDUQS
# 22                     Localiza
# 23                   Multilaser
# 24                         Zamp
# 25             Mahle Metal Leve
# 26                  BR Partners
# 27                   Portobello
# ...
